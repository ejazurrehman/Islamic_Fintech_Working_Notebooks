# %% [markdown]
# # Author Info
# ---
# Name: **Ejaz-ur-Rehman**\
# Business Unit Head | Data Analyst | Crystal Tech (Project of MUZHAB Group)\
# Faculty Member | PGP Corordinator | Department of Management Sciences | Al Ghazali University\
# MS (Finance), Associate Data Scientist (Python), PhD Scholar\
# Karachi, Pakistan
#
# ![Date](https://img.shields.io/badge/Date-8--August--2026-green?logo=google-calendar)
# [![Email](https://img.shields.io/badge/Email-ijazfinance%40gmail.com-blue?logo=gmail)](mailto:ejaz.rehman@agu.edu.pk)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Ejaz--ur--Rehman-blue?logo=linkedin)](https://www.linkedin.com/in/ejaz-ur-rehman/)
# [![GitHub](https://img.shields.io/badge/GitHub-ejazurrehman-black?logo=github)](https://github.com/ejazurrehman)

# %% [markdown]
# # Student Instructions
# ## Islamic FINTECH Final Practical Examination
# ### Examination Duration: 3 Hours
# #### Total Marks: 40 Marks

# %% [markdown]
# # Instructions
# 1. Read all questions carefully before attempting the examination.
# 2. This is an open-book practical examination. You may use your course notes, lecture slides, and other course materials.
# 3. You may use only your own laptop for the examination.
# 4. Internet access may be used only for Python documentation and package references, The use of AI tools (e.g., ChatGPT, Copilot, Gemini, Claude, etc.) during the examination are allowed.
# 5. Complete all tasks in the provided Jupyter Notebook (.ipynb) file.
# 6. Write your Python code only in the designated code cells. Do not modify, delete, or rearrange the existing notebook structure.
# 7. Wherever an Interpretation or Business Insight section is provided, explain your findings in clear and concise language. Marks will be awarded for both technical accuracy and analytical reasoning.
# 8. Unless otherwise instructed, all charts must include appropriate titles and axis labels.
# 9. Ensure that your notebook executes without errors before submission.
# 10. Save your notebook using the following naming convention:
#
#     Student_Name_Student_ID.ipynb
#
# 11. Uploading link will provide you druing the exam, you can upload your NB in between 4:00 PM to 5:00 PM
#
# > Important: Execute each code cell after writing your solution. Only executed cells with visible outputs will be considered for evaluation where applicable.

# %% [markdown]
# # Exploratory Data Analysis and Feature Engineering of the Islamic Banking Dataset for GCC Countries
# ## Background
#
# > Islamic banks generate large volumes of financial and regulatory data that support strategic pl nning, risk management, regulatory compliance, and business decision-making. Before such data can be used for advanced analytics or machine learning applications, it must be carefully examined, cleaned, and transformed into a reliable analytical dataset.
#
# > In this examination, you will work with a Global Islamic Banking Dataset, which contains financial and regulatory indicators of Islamic banking institutions across GCC countries. The dataset has been compiled from publicly available Islamic banking statistics and includes variables related to banking performance, assets, financing, deposits, capital adequacy, and other key financial indicators.
#
# > Your task is to perform a complete Exploratory Data Analysis (EDA) and Feature Engineering process to prepare the dataset for future predictive modelling and business intelligence applications.

# %% [markdown]
# ## Your Role
#
# > Assume that you have recently joined the Data Analytics Department of an Islamic Bank as a Junior Data Analyst. Your manager has assigned you the responsibility of evaluating the quality of the available banking data before it is used for developing Artificial Intelligence and Machine Learning models. You are expected to investigate the dataset, identify potential data quality issues, perform appropriate preprocessing, generate meaningful visualizations, engineer useful features, and communicate your findings through business-oriented interpretations.

# %% [markdown]
# ## Project Objectives
#
# During this examination, you are expected to:
#
# - Import and configure the required Python libraries.
# - Load and inspect the Islamic Banking dataset.
# - Assess the overall quality of the data.
# - Identify and handle missing values, duplicate records, and inconsistent data.
# - Perform Exploratory Data Analysis (EDA) using appropriate statistical summaries and visualizations.
# - Engineer meaningful features that could improve future machine learning models.
# - Interpret analytical results from both technical and business perspectives.
# - Present concise recommendations based on your analysis.

# %% [markdown]
# ## Data Source

# %% [markdown]
# The dataset used in this examination is based on data from the Islamic Financial Services Board (IFSB) and its Prudential and Structural Islamic Financial Indicators (PSIFIs) database.
#
# The IFSB Data Portal provides prudential and structural financial indicators for the Islamic Financial Services Industry. The PSIFIs are designed to provide internationally comparable information on the financial soundness, growth, structure, and risk characteristics of Islamic banking systems.
#
# Official Data Source: https://data.ifsb.org/?utm_source=chatgpt.com

# %% [markdown]
# ## Data Scope
# For this examination, the dataset has been prepared for practical analysis and contains observations relating to:
#
# - GCC countries
# - Quarterly reporting periods
# - Islamic banking indicators
# - Financial values
# - USD exchange rates
# - Values reported in USD millions
#
# > The dataset has been prepared and provided as part of this examination. Students are not required to download or collect additional data.

# %% [markdown]
# ## Expected Deliverables
#
# By the end of this examination, your submitted notebook should demonstrate your ability to:
#
# - Understand the structure and characteristics of a real-world financial dataset.
# - Apply appropriate data preprocessing techniques.
# - Generate meaningful statistical and graphical analyses.
# - Develop informative features from existing variables.
# - Communicate findings in a professional and business-oriented manner.
# - Produce clean, reproducible, and well-documented Python code.

# %% [markdown]
# ## Note to Students
#
# > This examination assesses not only your ability to write Python code but also your ability to interpret data, think analytically, and apply data science techniques to solve practical problems in the Islamic banking industry.

# %% [markdown]
# # Section 0
# Import required Libraries

# %%
# ============================================================
# Import Required Libraries
# (Pre-configured by the Instructor)
# ============================================================

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

plt.style.use("default")

# %% [markdown]
# > Note: The required libraries and notebook configuration have been preloaded. Students are not required to modify this section.

# %%
# ============================================================
# Load the Dataset (Pre-configured by the Instructor)
# ============================================================

df = pd.read_csv("Islamic_Banking_GCC_Data.csv", encoding="cp1252")

# Display confirmation
print("Dataset loaded successfully.")
# Out:
# Dataset loaded successfully.

# %% [markdown]
# ## Section 1: Understanding the Dataset (05 Marks)
# Objective
#
# The first step in any data analytics project is to understand the structure, composition, and characteristics of the dataset. Before performing data cleaning or analysis, a data analyst must inspect the dataset to identify the available variables, their data types, and the overall quality of the data.

# %% [markdown]
# ## Student Instructions
#
# Using the pre-loaded dataset `(df)`, perform an initial exploration of the data by completing the following tasks.

# %% [markdown]
# ### Task 1.1: Display the first five observations of the dataset.

# %%
# Display first five rows

# %% [markdown]
# ### Task 1.2: Display the last five observations of the dataset.

# %%
# Display last five rows

# %% [markdown]
# ### Task 1.3: Determine the number of rows and columns in the dataset.

# %%
# Dataset dimensions

# %% [markdown]
# ### Task 1.4: Determine the columns in the dataset.

# %%
# Column names

# %% [markdown]
# ### Task 1.5: Examine the data types.

# %%
# Data types

# %% [markdown]
# ### Task 1.6: Generate descriptive statistics.

# %%
# Descriptive statistics

# %% [markdown]
# ### Task 1.7: Identify missing values.

# %%
# Missing values

# %% [markdown]
# ## Answer the following Quesitons

# %% [markdown]
# ### 1. What is the size of the dataset?

# %% [markdown]
# ### 2. Which variables appear to be categorical?

# %% [markdown]
# ### 3. Which variables may require preprocessing?

# %% [markdown]
# ### 4. Write three observations.

# %% [markdown]
# ## Section 2: Data Quality Assessment (05 Marks)

# %% [markdown]
# ### Objective
#
# Before performing further analysis, assess the quality and reliability of the Islamic Banking dataset. Identify potential issues that may affect subsequent analysis and machine learning applications.

# %%
# ============================================================
# Section 2: Data Quality Assessment
# Total Marks: 05
# ============================================================

# %% [markdown]
# ## Student Instructions
#
# Using the pre-loaded dataset `(df)`, perform the following tasks.

# %% [markdown]
# ### Task 2.1: Identify the number of missing values in each variable.

# %%
# Identify the number of missing values in each variable

# %% [markdown]
# ### Task 2.2: Calculate the percentage of missing values for each variable.

# %%
# Calculate the percentage of missing values

# %% [markdown]
# ### Task 2.3: Identify Duplicate Records: Determine whether the dataset contains duplicate records and report the total number of duplicate observations.

# %%
# Identify duplicate records

# %% [markdown]
# ### Task 2.4: Examine Data Types: Examine the data type of each variable in the dataset.

# %%
# Examine data types

# %% [markdown]
# ### Task 2.5: Identify Inappropriate Data Types: Based on your examination of the data types, identify any variable whose current data type appears inappropriate for analysis.
#
# Provide a brief justification for your answer.

# %%
# Display data types together with sample values
# to support identification of potentially inappropriate types

# %% [markdown]
# ### Task 2.6: Examine Unique and Unusual Values
#
# Identify variables containing unique, unexpected, or unusual values that may require further investigation.
#
# Focus particularly on categorical variables.

# %%
# Examine unique values of categorical variables

# %% [markdown]
# ### For frequency-based inspection:

# %%
for col in categorical_columns:
    print(f"\n--- {col} ---")
    display(df[col].value_counts(dropna=False))
# Out:
# --- Country ---
# Country
# Oman                    17329
# Saudi Arabia            16940
# United Arab Emirates    10417
# Kuwait                   8228
# Bahrain                  8106
# Qatar                    6112
# Name: count, dtype: int64
# --- Regional Code ---
# Regional Code
# GCC    67132
# Name: count, dtype: int64
# --- Report Type ---
# Report Type
# Islamic Banking            49036
# Islamic Banking Windows    18096
# Name: count, dtype: int64
# --- Time Period ---
# Time Period
# 2021Q4    1726
# 2022Q1    1726
# 2022Q2    1726
# 2022Q3    1726
# 2022Q4    1726
# 2016Q4    1534
# 2017Q2    1534
# 2017Q3    1534
# 2019Q4    1534
# 2018Q2    1534
# 2018Q3    1534
# 2018Q1    1534
# 2017Q4    1534
# 2020Q2    1534
# 2020Q3    1534
# 2020Q1    1534
# 2017Q1    1534
# 2021Q3    1534
# 2021Q2    1534
# 2021Q1    1534
# 2020Q4    1534
# 2023Q1    1534
# 2023Q2    1534
# 2023Q3    1534
# 2018Q4    1534
# 2019Q1    1534
# 2019Q2    1534
# 2019Q3    1534
# 2013Q4    1343
# 2014Q2    1343
# 2014Q3    1343
# 2014Q1    1343
# 2015Q4    1343
# 2016Q2    1343
# 2016Q1    1343
# 2016Q3    1343
# 2014Q4    1343
# 2015Q1    1343
# 2015Q2    1343
# 2015Q3    1343
# 2023Q4    1341
# ST05_010             350
# ST05                 350
# ST04_080             350
# ST07                 350
# ST06                 350
# ST05_040             350
# ST04_050             350
# ST04_060             350
# ST04_070             350
# ST04_040             350
# ST04                 350
# ST04_030             350
# ST04_020             350
# ST04_010             350
# ST03_030             350
# ST03_040             350
# ST03_050             350
# ST03_020             350
# ST02                 350
# ST03                 350
# ST01_010             350
# ST01                 350
# ST05_020             350
# ST07_010_020         350
# ST07_010_030         350
# ST07_010_080         350
# ST07_010_090         350
# ST07_010_0100        350
# ST07_010_0110_020    350
# ST05_030             350
# ST07_010_010         350
# ST07_010_070         350
# ST07_010_060         350
# ST07_010             350
# ST07_010_040         350
# ST07_010_050         350
# AD08_010_0140        335
# CP10_010             318
# ST07_010_0110_010    318
# AD06_010_010         306
# AD06_010_010_010     306
# AD06_010_010_0240    306
# AD06_010_010_0280    306
# AD06_010_010_0290    306
# AD06_010_010_0300    306
# AD06_010_010_0310    306
# AD06_010_010_0250    306
# AD06_010_010_090     306
# AD06_010_010_020     306
# AD06_010_010_030     306
# AD06_010_010_060     306
# AD06_010_010_080     306
# AD06_010_010_040     306
# AD06_010_010_050     306
# AD06_010_010_0230    306
# AD06_010_010_0210    306
# AD06_010_010_0190    306
# AD06_010_010_0180    306
# AD06_010_010_0170    306
# AD06_010_010_0150    306
# AD06_010_010_0140    306
# AD06_010_010_0130    306
# AD06_010_010_0110    306
# ST03_010             306
# ST07_010_0110_040    306
# ST01_020             304
# AD06_010_020          44
# AD06_010_030          44
# AD06_010_040          44
# AD06_010_050          44
# AD06_010_0110         44
# AD06_010_060          44
# AD06_010_070          44
# AD06_010_070_010      44
# AD06_010_070_020      44
# AD06_010_080          44
# AD06_010_090          44
# AD06_010_0100         44
# AD06_010_0120_010     44
# AD06_010_0110_010     44
# AD06_010_0110_020     44
# AD06_010_0120         44
# AD06_010_0120_030     44
# AD06_010_0120_020     44
# AD06_010_0130         44
# AD08_010_050          15
# Name: count, dtype: int64
# --- Indicator Description ---
# Indicator Description
# Total regulatory capital                                                                                                                      1750
# RWA                                                                                                                                           1750
# Tier 1 capital                                                                                                                                1400
# Total assets                                                                                                                                  1050
# Others                                                                                                                                        1006
# Net income (before extraordinary items, taxes, and Zakat)-Annualised                                                                           700
# Gross income                                                                                                                                   700
# Gross NPF                                                                                                                                      700
# Liquid assets                                                                                                                                  700
# Suk?k holdings                                                                                                                                 700
# Total financing                                                                                                                                700
# CET1 capital                                                                                                                                   700
# Mush?rakah                                                                                                                                     700
# Qar? Hassan                                                                                                                                    700
# Mu??rabah                                                                                                                                      700
# Salam                                                                                                                                          700
# (iii)                                                                                                                                          700
# Diminishing Mush?rakah                                                                                                                         700
# Wak?lah                                                                                                                                        700
# Istisn?`                                                                                                                                       700
# (ii)                                                                                                                                           700
# Commodity Mur?bahah / Tawwaruq                                                                                                                 700
# Ij?rah/Ij?rah Muntahia Bittaml?k                                                                                                               685
# (i)                                                                                                                                            668
# (n) administrative and support service activities                                                                                              656
# (f)construction                                                                                                                                656
# (m)  professional, scientific and technical activities                                                                                         656
# (l)real estate activities                                                                                                                      656
# (d) electricity, gas, steam and air-conditioning supply                                                                                        656
# (e) water supply; sewerage and waste management                                                                                                656
# (c) manufacturing                                                                                                                              656
# (g) wholesale and retail trade; repair of motor vehicles and motorcycles                                                                       656
# (a) agriculture, forestry, hunting and fishing                                                                                                 656
# (b) mining and quarrying                                                                                                                       656
# (t) activities of households as employers                                                                                                      656
# (o) public administration and defense; compulsory social security                                                                              656
# (s) other service activities (export)                                                                                                          656
# (r)arts, entertainment and recreation                                                                                                          656
# (q) human health and social work activities                                                                                                    656
# (p) education                                                                                                                                  656
# (u*)   financing to nonresidents                                                                                                               656
# (u) activities of extraterritorial organisations and bodies                                                                                    656
# (t*)    other financing of households                                                                                                          656
# (h) transportation and storage                                                                                                                 656
# (k) financial and insurance activities                                                                                                         656
# (j)information and communication                                                                                                               656
# (i)accommodation and food service activities                                                                                                   656
# Tier 1 capital to RWA                                                                                                                          350
# Common Equity Tier 1 (CET1) capital to RWA                                                                                                     350
# CAR                                                                                                                                            350
# Risk-weighted assets (RWA)                                                                                                                     350
# Return on assets (ROA)                                                                                                                         350
# Net nonperforming financing (net NPF) to capital                                                                                               350
# Provisions                                                                                                                                     350
# Provisions for gross nonperforming financing (NPF)                                                                                             350
# Net NPF                                                                                                                                        350
# CAR (IFSB)                                                                                                                                     350
# Tier 1 capital to RWA  (IFSB)                                                                                                                  350
# Common Equity Tier 1 (CET1) capital to RWA (IFSB)                                                                                              350
# Gross nonperforming financing (NPF) ratio                                                                                                      350
# Value (or percentage) of financing by type of Shar?`ah-compliant contract                                                                      350
# Cost to income                                                                                                                                 350
# Net income (before extraordinary items, taxes, and Zakat)                                                                                      350
# Net profit margin                                                                                                                              350
# Return on equity (ROE)                                                                                                                         350
# Average equity                                                                                                                                 350
# Average total assets                                                                                                                           350
# Total funding                                                                                                                                  350
# FX financing                                                                                                                                   350
# Foreign-currency denominated financing to total financing                                                                                      350
# Total financing at end of same period in previous year                                                                                         350
# Total financing at end of current period                                                                                                       350
# Growth of financing to private sector                                                                                                          350
# Total regulatory capital (or balance sheet capital)                                                                                            350
# Value of large exposures                                                                                                                       350
# Large exposures to capital                                                                                                                     350
# Net FX open position                                                                                                                           350
# Net foreign exchange open position to capital                                                                                                  350
# Required stable funding (RSF)                                                                                                                  350
# FX funding                                                                                                                                     350
# Foreign-currency denominated funding to total funding                                                                                          350
# Off-balance sheet items                                                                                                                        350
# Total off-balance sheet items to total assets                                                                                                  350
# Total income from assets funded by PSIA                                                                                                        350
# Income distributed to IAH                                                                                                                      350
# Income distributed to investment account holder (IAH) out of total income from assets funded by profit-sharing investment accounts (PSIAs)     350
# Leverage (regulatory definition)                                                                                                               350
# Capital to assets (balance sheet definition)                                                                                                   350
# Exposure                                                                                                                                       350
# Liquid assets ratio                                                                                                                            350
# Liquid assets to short-term liabilities                                                                                                        350
# Short-term liabilities                                                                                                                         350
# Mur?bahah                                                                                                                                      350
# Value (or percentage) of returns by major type of Shar?`ah-compliant contract                                                                  350
# Value of gross NPF                                                                                                                             350
# Economic activity                                                                                                                              350
# Value (or percentage) of Shar?`ah-compliant financing by economic activity                                                                     350
# Value of Suk?k holdings to capital                                                                                                             350
# Value of Shar?`ah-compliant financing                                                                                                          350
# Value (or percentage) of gross NPF by economic activities                                                                                      350
# Liquidity coverage ratio (LCR)                                                                                                                 350
# Stock of Shar?`ah-compliant  high quality liquid assets                                                                                        350
# Total net cash outflows over the next 30 calendar days                                                                                         350
# Net stable funding ratio (NSFR)                                                                                                                350
# Available stable funding (ASF)                                                                                                                 350
# Total returns                                                                                                                                  350
# Mur?bahah                                                                                                                                      350
# Others                                                                                                                                         350
# Number of Islamic banks                                                                                                                        350
# Number of domestic branch offices                                                                                                              350
# Number of employees                                                                                                                            350
# Total assets                                                                                                                                   350
# Interbank financing                                                                                                                            350
# Other Shar?`ah-compliant securities                                                                                                            350
# Total funding/liabilities and equities                                                                                                         350
# All other assets                                                                                                                               350
# Nonremunerative funding (current account, Wad?`ah)                                                                                             350
# Suk?k issued                                                                                                                                   350
# Profit-sharing investment accounts (PSIA)                                                                                                      350
# Other remunerative funding (Mur?bahah, Commodity Mur?bahah etc.)                                                                               350
# Other Shar?`ah-compliant securities issued                                                                                                     350
# Interbank funding/liabilities                                                                                                                  350
# Capital and reserves                                                                                                                           350
# All other liabilities                                                                                                                          350
# Assets held by domestic systemically important Islamic banks                                                                                   350
# Total financing                                                                                                                                350
# Total revenues                                                                                                                                 350
# Financing based                                                                                                                                350
# Investment based (Suk?k, other Shar?`ah-compliant securities etc.)                                                                             350
# Fee based                                                                                                                                      350
# Other                                                                                                                                          350
# Earnings before taxes and Zakat                                                                                                                350
# Operating costs                                                                                                                                318
# Sectoral distribution                                                                                                                          306
# Total Shar?`ah-compliant financing (excluding interbank financing)                                                                             306
# Number of ATMs                                                                                                                                 304
# Oil/gas                                                                                                                                         44
# Trade                                                                                                                                           44
# Industry                                                                                                                                        44
# Construction                                                                                                                                    44
# Services                                                                                                                                        44
# Real Estate                                                                                                                                     44
# Equity purchase loans                                                                                                                           44
# Of which: Corporate                                                                                                                             44
# Of which: individuals                                                                                                                           44
# Agriculture/fishing                                                                                                                             44
# Investment companies                                                                                                                            44
# Banks                                                                                                                                           44
# Of which: Credit card advances                                                                                                                  44
# Of which: Public                                                                                                                                44
# Of which: Private (e.g.. Telecommunication)                                                                                                     44
# Households                                                                                                                                      44
# Of which: Consumer loans                                                                                                                        44
# Of which: Installment Loans                                                                                                                     44
# Other                                                                                                                                           44
# Ij?rah/ Ij?rah Muntahia Bittaml?k/ Hire Purchase/ HPSM                                                                                          15
# Name: count, dtype: int64
# --- currency ---
# currency
# NC     48628
#        11964
# USD     6480
# n.a       60
# Name: count, dtype: int64
# --- units ---
# units
# M      36013
# K      19085
#        10680
# n.a     1354
# Name: count, dtype: int64
# --- Values ---
# Values
#                 22871
# 0                6493
# 4                  84
# 6                  81
# 0.2                76
# 2                  69
# 8                  65
# 1                  62
# 1.3                52
# 0.91               52
# 0.44               49
# 1.5                49
# 4.93               47
# 5.99               47
# 0.54               46
# 29.6               46
# 17.14              46
# 6.22               46
# 5.13               45
# 10.99              45
# 7.62               45
# 4.55               45
# 22.98              44
# 5.29               44
# 0.58               44
# 3.69               44
# 21                 26
# 100                26
# 5                  25
# 7                  24
# 10                 22
# 32                 21
# 23                 19
# 16                 17
# 963                17
# 9                  16
# 14                 16
# 55                 14
# 64                 14
# 15                 13
# 53                 13
# 20                 13
# 24                 13
# 179                13
# 17                 12
# 90205              12
# 25                 12
# 1918               12
# 1887               12
# 3                  12
# 1.25               11
# 46                 11
# 10.56              10
# 1.4                10
# 50                 10
# 18                 10
# 60                 10
# 1000               10
# 2.26               10
# 170                10
# 11                  9
# 178                 9
# 1571                9
# 0.89                9
# 0.88                9
# 1.16                9
# 1.38                9
# 17.94               9
# 24620               9
# 2.1                 9
# 19                  8
# 1.02                8
# 10.19               8
# 18.22               8
# 147                 8
# 1.36                8
# 13                  8
# 17.37               8
# 2.39                8
# 1.24                8
# 284                 8
# 283                 8
# 1.87                8
# 44608               8
# 22                  8
# 13.65               8
# 14.64               8
# 1.01                8
# 80                  8
# 1.14                8
# 0.9                 8
# 17.52               7
# 563671296           7
# 58                  7
# 34                  7
# 31                  7
# 16.94               7
# 18.27               7
# 7.65                7
# 16.7                7
# 13.99               7
# 29                  7
# 4007                7
# 68                  7
# 17.2                7
# 0.1                 7
# 0.38                7
# 360938091           7
# 19.06               7
# 71                  7
# 18.34               7
# 61                  7
# 14.52               7
# 0.03                7
# 48                  7
# 0.84                7
# 105.6               7
# 1.69                7
# 12.5                7
# 0.87                7
# 16.02               7
# 0.09                7
# 1.22                7
# 15.03               7
# 126                 7
# 1.06                7
# 17.93               7
# 14.6                7
# 2.17                7
# 12                  7
# 9.1                 7
# 15.57               7
# 10.61               7
# 12.97               7
# 731                 7
# 1.42                6
# 2442001.9           6
# 2083821             6
# 2093459.9           6
# 0.26                6
# 1.77                6
# 0.33                6
# 0.85                6
# 7.04                6
# 54354.57            6
# 2256793.7           6
# 1474469             6
# 11.1                6
# 588753.89           6
# 603980.35           6
# 1.13                6
# 1391962             6
# 587584.14           6
# 0.18                6
# 601687.99           6
# 19.04               6
# 1105443             6
# 40810.71            6
# 2954061.87          6
# 21036.95            6
# 218013              6
# 1900487             6
# 2951.07             6
# 1833523.6           6
# 36                  6
# 1782499.4           6
# 582449.3            6
# 43122.3             6
# 13.17               6
# 16.41               6
# 1481062.9           6
# 98                  6
# 0.64                6
# 78033853            6
# 12.94               6
# 378300829           6
# 2545841             6
# 14.29               6
# 15.91               6
# 1314719             6
# 2120562             6
# 3109.47             6
# 12928.46            6
# 1072254.4           6
# 601535              6
# 1016275.3           6
# 475166              6
# 915284.4            6
# 595737.62           6
# 1.19                6
# 512483              6
# 397106              6
# 73                  6
# 2.21                6
# 74                  6
# 0.98                6
# 5076170.9           6
# 1187590             6
# 1.15                6
# 30                  6
# 12956.43            6
# 57984.19            6
# 105592.9            6
# 37675               6
# 0.76                6
# 2389884             6
# 298349              6
# 111962.5            6
# 59865.93            5
# 2333146.1           5
# 488950              5
# 237132.5            5
# 2200320.5           5
# 11.08               5
# 43                  5
# 70137.58            5
# 236552.2            5
# 0.77                5
# 11.81               5
# 2115453.7           5
# 207792.2            5
# 1677044.1           5
# 235199              5
# 1.52                5
# 1907413             5
# 1560760.1           5
# 530236114           5
# 46985.01            5
# 1.44                5
# 360782              5
# 221505.1            5
# 1870067.7           5
# 2.48                5
# 43568.38            5
# 421212321           5
# 1.11                5
# 0.72                5
# 352202189           5
# 215740.4            5
# 561117737           5
# 532085645           5
# 56447.35            5
# 1356046.2           5
# 210959              5
# 4708.76             5
# 215752              5
# 0.3                 5
# 4458.13             5
# 214777.5            5
# 118                 5
# 1603968.2           5
# 2.25                5
# 1.7                 5
# 1288948.9           5
# 343097              5
# 189365.7            5
# 544293276           5
# 1350866.4           5
# 394228354           5
# 58463.66            5
# 14.59               5
# 482868106           5
# 38921.57            5
# 211214              5
# 6534.95             5
# 212697              5
# 153056.9            5
# 1313583.1           5
# 17.79               5
# 152690.2            5
# 1072870.7           5
# 38126.75            5
# 0.5                 5
# 48759.81            5
# 1587461             5
# 134701.5            5
# 39                  5
# 21984.29            5
# 973690              5
# 61436.83            5
# 6.94                5
# 829907              5
# 131366              5
# 2150751             5
# 673                 5
# 19.98               5
# 899458              5
# 113030              5
# 100059              5
# 0.27                5
# 2508933.3           5
# 42621.17            5
# 38949.85            5
# 31853.36            5
# 499041              5
# 295                 5
# 343                 5
# 6594.07             5
# 13.49               5
# 95021               5
# 396838558           5
# 0.92                5
# 205460              5
# 19.17               5
# 677518.5            5
# 21429.19            5
# 229550              5
# 14.84               5
# 1.41                5
# 48800.58            5
# 6756.39             5
# 17.73               5
# 51                  5
# 964221.3            5
# 2.23                5
# 4197.67             5
# 2784833             5
# 45514.3             5
# 66458.62            5
# 13.86               5
# 0.75                5
# 5076.96             5
# 180                 5
# 15.22               5
# 1265596             5
# 75                  5
# 9.73                5
# 916180              5
# 551588              5
# 207450.3            5
# 208547              5
# 5711.97             5
# 17.41               5
# 888303.7            5
# 38937.18            5
# 16.55               5
# 0.97                5
# 44537.95            5
# 1.31                5
# 839374.4            5
# 338573              5
# 19.41               5
# 41043.48            5
# 3379412             5
# 1.17                5
# 253885              5
# 794773              5
# 37018.57            5
# 17.85               5
# 348951588           5
# 342550              5
# 63122.86            5
# 18.51               5
# 14.12               5
# 729264.1            5
# 337586369           5
# 703058.6            5
# 4332.22             5
# 692066              5
# 666964              5
# 650044.6            5
# 44756.49            5
# 1.04                5
# 32.74               5
# 11.77               5
# 11.84               5
# 630728.7            5
# 16.92               5
# 604359.7            5
# 608839.6            5
# 1444896             5
# 2.13                5
# 21682.88            5
# 222568              5
# 605634.5            5
# 2711898             5
# 15.36               5
# 590347.5            5
# 31.25               5
# 597728.9            5
# 215643              5
# 601466.9            5
# 2802216             5
# 1.43                5
# 603962.3            5
# 206724              5
# 598823              5
# 1.37                5
# 619105.8            5
# 1026013.5           5
# 42942.59            5
# 0.04                5
# 599722.8            5
# 548850238           5
# 575003.9            5
# 26                  5
# 352175926           5
# 38146.73            5
# 572843.3            5
# 18.5                5
# 14.28               5
# 565666              5
# 565792.7            5
# 13.98               5
# 4977.81             5
# 423                 5
# 5473343.2           5
# 44390.66            5
# 37400.68            5
# 4380643.3           5
# 350044587           5
# 5458814             5
# 4304251.7           5
# 67333.35            5
# 5258154.9           5
# 17.7                5
# 402191614           5
# 4199309.8           5
# 40474.31            5
# 341234              5
# 2493969.2           5
# 209837              5
# 4272.34             5
# 62977.96            5
# 213970              5
# 232                 5
# 4104556             5
# 13.25               5
# 578520.7            5
# 582576.1            5
# 564958              5
# 13.34               5
# 6163.22             5
# 4321883.4           5
# 47484.61            5
# 521447.4            5
# 534859.79           5
# 351726              5
# 8.46                5
# 16.13               5
# 492998.6            5
# 452047.6            5
# 11.13               5
# 2309828.8           5
# 444836.5            5
# 564484867           5
# 4154494.74          5
# 3448266.3           5
# 0.02                5
# 12.82               5
# 431487.8            5
# 21978.35            5
# 15.2                5
# 483883.07           5
# 19.13               5
# 403940.4            5
# 42628.19            5
# 401869.3            5
# 4075281.1           5
# 6651.99             5
# 9.39                5
# 3384122.4           5
# 1753196             5
# 0.96                5
# 389200.2            5
# 15.8                5
# 0.31                5
# 58.32               5
# 377606              5
# 426309082           5
# 490509.5            5
# 43050.23            5
# 2071934.5           5
# 11.78               5
# 0.21                5
# 217298              5
# 0.83                5
# 322867623           5
# 37314.68            5
# 4712.8              5
# 600986.1            5
# 415750526           5
# 5964.5              5
# 897641              5
# 223664              5
# 3789108.03          5
# 3256675.7           5
# 221819              5
# 474128.18           5
# 13.58               5
# 352803197           5
# 0.16                5
# 37636.07            5
# 64081.94            5
# 1.47                5
# 80.9                5
# 207370.8            5
# 337572              5
# 450628012           5
# 37205.77            5
# 1.62                5
# 43551.84            5
# 480801.85           5
# 358649785           5
# 13.74               5
# 15.37               5
# 15.84               5
# 47                  5
# 710                 5
# 3258465             5
# 6.77                5
# 3635646.2           5
# 208427              5
# 329627294           5
# 49                  5
# 326681              5
# 0.35                5
# 218917              5
# 269066              5
# 0.45                5
# 563844461           5
# 45858.41            5
# 205890              5
# 435026.1            5
# 375342759           5
# 219833              5
# 13.2                5
# 350724.94           5
# 0.81                5
# 17.04               5
# 2376983             5
# 45597               5
# 2700189             5
# 822156.4            5
# 19.48               5
# 41892.02            5
# 21747.17            5
# 3537901.4           5
# 1554980             5
# 436340336           5
# 374192              5
# 1.56                5
# 12.84               5
# 17.06               5
# 389644575           5
# 663489.4            5
# 36600.39            5
# 43738.7             5
# 207429.6            5
# 433534.8            5
# 15.88               5
# 1482486             5
# 4834.84             5
# 8.87                5
# 15.02               5
# 2256100.3           5
# 1.09                5
# 3412472             5
# 44262.66            5
# 0.4                 5
# 1726522             5
# 64568.33            5
# 1.54                5
# 10.59               5
# 3459212.3           5
# 1668164             5
# 575906334           5
# 16.04               5
# 2848203             5
# 11.39               5
# 431426.82           5
# 17.9                5
# 2401863             5
# 2030873             5
# 15.76               5
# 101554              4
# 13375.11           1
# 5373.04            1
# 7002.75            1
# 3075.48            1
# 34.22              1
# 10195.32           1
# 29797.14           1
# 23.41              1
# 8716.3             1
# 37842.21           1
# 9003.78            1
# 5748.1             1
# 3126.92            1
# 1816.86            1
# 2006.8             1
# 6672.4             1
# -13.08             1
# 16330.48           1
# 18788.92           1
# 15394.31           1
# 1485.83            1
# 21167.03           1
# 3102.19            1
# 409.69             1
# 281.25             1
# 1861.46            1
# 56023.88           1
# 30.1               1
# 37350.99           1
# 9460.07            1
# 3137.15            1
# 5013.61            1
# 13931.52           1
# 4628.92            1
# 7181.51            1
# 3466.9             1
# 3361.25            1
# 2941.78            1
# 23090.24           1
# 2098.57            1
# 1549.76            1
# 396.46             1
# 240.54             1
# 456.76             1
# 3578.27            1
# 16575.63           1
# 2482.23            1
# 7460.48            1
# 3357.25            1
# 17677.22           1
# 1948.18            1
# 7268.35            1
# 31.89              1
# 9528.47            1
# 29875.62           1
# 9587.88            1
# 39244.77           1
# 8860.91            1
# 34.17              1
# 7419.66            1
# 2125.82            1
# 33.15              1
# 2587.73            1
# 7807.07            1
# -6.72              1
# 16762.4            1
# 17969.91           1
# 15714.55           1
# 8661.18            1
# 37271.59           1
# 9266.6             1
# 8171.87            1
# 3641.47            1
# 598                1
# 2254.37            1
# 160.1              1
# 8180.5             1
# -9.84              1
# 15573.1            1
# 16259.63           1
# 32.07              1
# 9703.04            1
# 30255              1
# 23.64              1
# 158.42             1
# 121.14             1
# 45.28              1
# 2.86               1
# 57.48              1
# 1785.65            1
# 58761.69           1
# 3256.3             1
# 651.91             1
# 1040.74            1
# 2563.4             1
# 24869.43           1
# 1829.35            1
# 1594.36            1
# 1039.4             1
# 275.4              1
# Name: count, dtype: int64

# %% [markdown]
# ## Section 3: Data Cleaning (05 Marks)

# %% [markdown]
# ### Objective
#
# Prepare the dataset for further analysis by correcting formatting issues, handling missing values appropriately, converting variables to suitable data types, and verifying the quality of the cleaned dataset.

# %% [markdown]
# ### Task 3.1: Standardize Text Variables
#
# Remove unnecessary leading and trailing spaces from the categorical/text variables.

# %%
# Identify text variables
text_columns = df.select_dtypes(include="object").columns

# Remove leading and trailing spaces
for col in text_columns:
    df[col] = df[col].str.strip()

# %% [markdown]
# ### Task 3.2: Convert Blank Values to Missing Values
#
# The dataset may contain blank strings that are not automatically recognized as missing values.Identify blank or empty values and convert them into appropriate missing-value representations.

# %%
# Replace blank or whitespace-only strings with NaN

# %%
# Display the number of missing values in each variable after cleaning

# %% [markdown]
# ### Task 3.3: Convert Numerical Variables to Appropriate Data Types
#
# Identify the financial variables that should be numerical and convert them to appropriate numeric data types.
#
# The following variables should be examined:
#
# - USD Exchange Rate
# - Values
# - Values in USD Millions

# %%
# Convert numeric columns to appropriate data types
numeric_columns = [
    "USD Exchange Rate",
    "Values",
    "Values in USD Millions"
]

for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# %%
# Display the data types of the numeric columns after conversion
display(df[numeric_columns].dtypes)
# Out:
# USD Exchange Rate         float64
# Values                    float64
# Values in USD Millions    float64
# dtype: object

# %% [markdown]
# ### Task 3.4: Handle Duplicate Records
#
# > Check the dataset for duplicate observations.
#
# > If duplicate records are present, remove them appropriately. If no duplicates are present, report the result.

# %%
# Identify and remove duplicate records


# Remove duplicate records

# %% [markdown]
# ### Task 3.5: Review the missing values remaining after the previous cleaning steps.
#
# For each type of missing value, determine an appropriate treatment based on the nature of the variable.
#
# > Important: Do not automatically replace all missing values with the mean, median, or zero. Your treatment should be justified.

# %%
# Find the missing values summary after cleaning and removing duplicates

# %%
# Keep missing observations at this stage where
# missingness may represent unreported/not-applicable data.

print("Missing values retained for appropriate analysis.")
# Out:
# Missing values retained for appropriate analysis.

# %% [markdown]
# ### Task 3.6: Verify the Cleaned Dataset
#
# After completing the cleaning process, verify that the dataset is ready for further analysis.
#
# Check:
#
# - Data types
# - Remaining missing values
# - Duplicate records
# - Dataset dimensions

# %%
# Show the final dataset shape, data types, missing values, and duplicate records after cleaning

# %% [markdown]
# ## Section 4: Univariate Analysis (05 Marks)

# %% [markdown]
# ### Objective
#
# Perform univariate analysis to understand the distribution, frequency, and basic characteristics of individual categorical and numerical variables in the Islamic Banking dataset.

# %% [markdown]
# ### Task 4.1: Identify Categorical and Numerical Variables
#
# Identify the variables that are:
#
# - Categorical
# - Numerical

# %%
# Identify categorical variables


# Identify numerical variables

# %% [markdown]
# ### Task 4.2: Analyse Categorical Variables
#
# For each categorical variable, determine the frequency of its categories.
#
# Display the 10 most frequent categories for each categorical variable.

# %%
# Display the categorical and numerical variables

# %% [markdown]
# ### Task 4.3: Analyse Numerical Variables
#
# Generate descriptive statistics for the numerical variables, including:
#
# - Count
# - Mean
# - Standard deviation
# - Minimum
# - Quartiles
# - Maximum

# %%
# Display the summary statistics for numerical variables

# %% [markdown]
# ### Task 4.4: Identify Dominant Categories
#
# Identify the most frequently occurring category for the major categorical variables.
#
# For example:
#
# - Country
# - Report Type
# - Currency
# - Units

# %%
# Display the top category and its frequency for each categorical variable

# %% [markdown]
# ### Task 4.5: Interpret the Numerical Variables
#
# Based on the descriptive statistics, identify:
#
# 1. The numerical variable with the highest variability.
# 2. The variable with the largest range between minimum and maximum values.
# 3. Any variable that appears to contain potentially extreme observations.

# %%
# Calculate the range (max - min) for each numeric variable

# %%
# Calculate the standard deviation for each numeric variable to assess variability

# %% [markdown]
# ### Interpretation

# %% [markdown]
# ## Section 5: Data Visualizaiton (05 Marks)

# %% [markdown]
# ### Objective
#
# Use appropriate graphical techniques to visualize the distribution and characteristics of variables in the Islamic Banking dataset. Interpret the visualizations from both statistical and business perspectives.

# %% [markdown]
# ### Task 5.1: Country Distribution
#
# Create a bar chart showing the top 10 countries by number of observations in the dataset.
#
# Your chart must include:
#
# - Appropriate title
# - X-axis label
# - Y-axis label
# - Readable category labels

# %%
# Display the distribution of the top 10 countries by number of observations using a bar plot

# %% [markdown]
# ### Interpretation

# %% [markdown]
# ### Task 5.2: Financial Value Distribution
#
# The variable Values in USD Millions contains observations with substantially different magnitudes. Create an appropriate visualization to examine its distribution.
#
# You should:
#
# 1. Examine the distribution of the variable.
# 2. If the distribution is highly skewed, apply an appropriate transformation for visualization.
# 3. Create a histogram of the transformed values.
# 4. Clearly label the chart.

# %%
# Create a log-transformed version for visualization

# %% [markdown]
# ### Interpretation

# %% [markdown]
# ### Task 5.3: Identify Potential Outliers
#
# Create a boxplot of the log-transformed financial values created in Task 5.2 to investigate potential extreme observations.

# %%
# Create a boxplot for the "Values in USD Millions" variable to visualize its distribution and identify potential outliers

# %% [markdown]
# ### Interpretation
#
#
# 1. Does the boxplot indicate potential outliers?
# 2. Why should an observation identified as an outlier not automatically be removed from a financial dataset?

# %% [markdown]
# ### Task 5.4: Comparative Financial Analysis
# Analyse the distribution of Total Financing across GCC countries.
#
# Using the Indicator Description variable:
#
# - Filter the dataset to include only observations where the indicator is Total financing.
# - Calculate the average value of Total Financing in USD Millions for each country.
# - Create a horizontal bar chart comparing the average Total Financing across the six GCC countries.
# - Sort the countries from lowest to highest average Total Financing.
# - Add an appropriate title and axis labels.

# %%
# Filter the dataset for Total Financing


# Calculate average financing by country

# %%
# Create a horizontal bar plot for average financing by country

# %% [markdown]
# ## Section 6: Time Analysis (05 Marks)

# %% [markdown]
# ### Objective
#
# Analyse the movement of Islamic banking financing over time using the quarterly reporting periods available in the dataset.

# %% [markdown]
# ### Task 6.1: Examine the Reporting Period
#
# Examine the Time Period variable and identify:
#
# - The earliest reporting period.
# - The latest reporting period.
# - The total number of reporting periods.

# %%
# Number of unique reporting periods


# Earliest reporting period


# Latest reporting period

# %% [markdown]
# ### Task 6.2: Prepare the Time Period Variable
#
# The Time Period variable is recorded in quarterly format, such as:
# > Convert the Time Period variable into a quarterly pandas Period format and create a new variable named Quarter

# %%
# Create a new column for the quarter of each reporting period and display the first five rows of the updated dataset

# %% [markdown]
# ### Task 6.3: Analyse Total Financing Over Time
#
# Using Total financing from Indicator Description:
#
# - Filter the dataset for Total Financing.
# - Calculate the average Total Financing in USD Millions for each reporting period.
# - Display the results in chronological order.

# %%
# Filter the dataset for Total Financing
financing_time = df[
    df["Indicator Description"] == "Total financing"
].copy()

# Convert financial value to numeric
financing_time["Values in USD Millions"] = pd.to_numeric(
    financing_time["Values in USD Millions"],
    errors="coerce"
)

# Average financing by reporting period
quarterly_financing = (
    financing_time
    .groupby("Quarter")["Values in USD Millions"]
    .mean()
    .sort_index()
)

display(quarterly_financing)
# Out:
# Quarter
# 2013Q4    4.483943e+04
# 2014Q1    4.698505e+04
# 2014Q2    4.995076e+04
# 2014Q3    5.165157e+04
# 2014Q4    5.287042e+04
# 2015Q1    5.413258e+04
# 2015Q2    5.593970e+04
# 2015Q3    5.644989e+04
# 2015Q4    5.838034e+04
# 2016Q1    6.071590e+04
# 2016Q2    6.246147e+04
# 2016Q3    6.260143e+04
# 2016Q4    6.253777e+04
# 2017Q1    6.375545e+04
# 2017Q2    6.507385e+04
# 2017Q3    6.581785e+04
# 2017Q4    6.536958e+04
# 2018Q1    6.594156e+04
# 2018Q2    6.660625e+04
# 2018Q3    6.757040e+04
# 2018Q4    6.788843e+04
# 2019Q1    6.869133e+04
# 2019Q2    6.978144e+04
# 2019Q3    7.152770e+04
# 2019Q4    7.345260e+04
# 2020Q1    7.581685e+04
# 2020Q2    7.825034e+04
# 2020Q3    8.021770e+04
# 2020Q4    8.257352e+04
# 2021Q1    8.558578e+04
# 2021Q2    8.798604e+04
# 2021Q3    8.984732e+04
# 2021Q4    8.597199e+04
# 2022Q1    8.941236e+04
# 2022Q2    9.198395e+04
# 2022Q3    9.421967e+04
# 2022Q4    9.922823e+04
# 2023Q1    1.078460e+05
# 2023Q2    1.097905e+05
# 2023Q3    1.119314e+05
# 2023Q4    1.178285e+05
# 2024Q1    1.695065e+05
# 2024Q2    1.746347e+05
# 2024Q3    1.732655e+05
# 2024Q4    3.600151e+06
# 2025Q1    3.684498e+06
# 2025Q2    3.097687e+06
# 2025Q3    3.153823e+06
# 2025Q4    1.620014e+05
# Freq: Q-DEC, Name: Values in USD Millions, dtype: float64

# %% [markdown]
# ### Task 6.4: Visualize the Financing Trend
#
# Create a line chart showing the average Total Financing over the reporting periods.
#
# Your chart must include:
#
# - Appropriate title
# - X-axis label
# - Y-axis label
# - Clearly ordered time periods

# %%
# Create a line plot for average financing over time
plt.figure(figsize=(12, 5))

# Plotting the average total financing over time
plt.plot(
    quarterly_financing.index.astype(str),
    quarterly_financing.values,
    marker="o"
)

plt.title("Average Total Financing Over Time")
plt.xlabel("Reporting Period")
plt.ylabel("Average Total Financing (USD Millions)")

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 6.5: Interpret the Trend
#
# Based on your analysis and visualization, answer the following:
#
# 1. What overall trend do you observe in Total Financing?
# 2. Are there periods of noticeable increase or decrease?
# 3. What does the trend suggest about the development of Islamic banking financing over the observed period?

# %% [markdown]
# ## Section 7: Correlation Analysis (05 Marks)

# %% [markdown]
# ### Objective
#
# Examine the relationships between numerical variables in the Islamic Banking dataset using correlation analysis and interpret the strength and direction of those relationships.

# %% [markdown]
# ### Task 7.1: Prepare Numerical Variables
#
# Identify all numerical variables that can be included in the correlation analysis.

# %%
# Identify numerical variables
num_cols = df.select_dtypes(include=np.number).columns.tolist()

print("Numerical Variables:")
print(num_cols)

# %% [markdown]
# ### Task 7.2: Generate the Correlation Matrix
#
# Calculate the Pearson correlation matrix for the numerical variables.
#
# Display the resulting correlation matrix.

# %%
# Calculate Pearson correlation matrix
corr = df[num_cols].corr(method="pearson")

display(corr)

# %% [markdown]
# ### Task 7.3: Visualize the Correlation Matrix
#
# Create a correlation heatmap using the numerical variables.
#
# Your heatmap should:
#
# - Display correlation coefficients.
# - Use an appropriate colour scale.
# - Include a meaningful title.
# - Clearly display variable names.

# %%
# Create a heatmap to visualize the correlation matrix

# %% [markdown]
# ### Task 7.4: Identify Strong Relationships
#
# Using the correlation matrix, identify:
#
# - The pair of numerical variables with the strongest positive correlation.
# - The pair of numerical variables with the strongest negative correlation, if one exists.
# - One pair with a relatively weak correlation.

# %%
# Extract the upper triangle of the correlation matrix
upper = corr.where(
    np.triu(np.ones(corr.shape), k=1).astype(bool)
)

# Convert correlations into a long-format table
corr_pairs = (
    upper
    .stack()
    .reset_index()
)

corr_pairs.columns = ["Variable 1", "Variable 2", "Correlation"]

# Sort by correlation
corr_pairs_sorted = corr_pairs.sort_values(
    "Correlation",
    ascending=False
)

display(corr_pairs_sorted.head(10))

# %% [markdown]
# ### Strongest positive correlation

# %%
strongest_positive = corr_pairs.loc[
    corr_pairs["Correlation"].idxmax()
]

display(strongest_positive)

# %% [markdown]
# ### Strongest negative correlation

# %%
strongest_negative = corr_pairs.loc[
    corr_pairs["Correlation"].idxmin()
]

display(strongest_negative)

# %% [markdown]
# ### Weakest relationship

# %%
weakest_relationship = corr_pairs.loc[
    corr_pairs["Correlation"].abs().idxmin()
]

display(weakest_relationship)

# %% [markdown]
# ### Task 7.5: Interpret the Correlations
#
# For the strongest relationship identified in Task 7.4, explain:
#
# 1. The direction of the relationship.
# 2. The strength of the relationship.
# 3. What the relationship may indicate from an Islamic banking perspective.
#
# | Correlation | Interpretation                 |
# | ----------: | ------------------------------ |
# | Close to +1 | Strong positive relationship   |
# | Close to -1 | Strong negative relationship   |
# |  Close to 0 | Weak or no linear relationship |

# %% [markdown]
# ## Section 8: Feature Engineering (2.5 Marks)

# %% [markdown]
# ### Objective
#
# Create meaningful new features from the existing Islamic Banking dataset that can support future statistical analysis, machine learning, and business intelligence applications.

# %% [markdown]
# ### Task 8.1: Create Year and Quarter Features
#
# The dataset contains quarterly reporting periods in the Time Period variable.
#
# Create two new variables:
#
# - Year
# - Quarter_Number
# - Quatter_Label

# %%
# Create Year and Quarter features
df["Year"] = df["Quarter"].dt.year
df["Quarter_Number"] = df["Quarter"].dt.quarter

# %%
# Create a Quarter_Label feature for better visualization and interpretation
df["Quarter_Label"] = "Q" + df["Quarter_Number"].astype(str)

# %% [markdown]
# ### Verification

# %%
# Display the first 10 rows of the new features
display(
    df[
        ["Time Period", "Year", "Quarter_Number", "Quarter_Label"]
    ].head(10)
)

# %% [markdown]
# ### Task 8.2: Create a Log-Transformed Financial Feature
#
# The Values in USD Millions variable contains highly skewed financial observations.
#
# Create a new feature called:
#
# Log_Values_USD_Millions
#
# using an appropriate logarithmic transformation.

# %%
# Create a log-transformed financial feature
df["Log_Values_USD_Millions"] = np.log1p(
    df["Values in USD Millions"]
)

# %% [markdown]
# ### Verification

# %%
# Display the first 10 rows of the original and log-transformed values
display(
    df[
        ["Values in USD Millions", "Log_Values_USD_Millions"]
    ].head(10)
)

# %% [markdown]
# ### Interpretation
#
# Explain:
#
# 1. Why is a logarithmic transformation useful for highly skewed financial data?
# 2. Why should the original Values in USD Millions variable be retained?

# %% [markdown]
# ### Task 8.3: Create a Financing Indicator Feature
#
# Create a binary feature called:
#
# Is_Financing
#
# The feature should take:
#
# - 1 if Indicator Description contains the word "financing"
# - 0 otherwise
#
# This feature will allow future analysis to distinguish financing-related indicators from other Islamic banking indicators.

# %%
# Create a binary feature indicating whether the observation is related to financing
df["Is_Financing"] = (
    df["Indicator Description"]
    .str.contains("financing", case=False, na=False)
    .astype(int)
)

# %% [markdown]
# ### Verification

# %%
# Display the distribution of the Is_Financing feature
display(
    df["Is_Financing"]
    .value_counts()
    .sort_index()
)

# %% [markdown]
# ### Task 8.4: Assess the Engineered Features
#
# Display the following five variables together:
#
# - Time Period
# - Year
# - Quarter_Number
# - Quarter_Label
# - Log_Values_USD_Millions
# - Is_Financing

# %%
# Display the first 10 rows of the relevant features
display(
    df[
        [
            "Time Period",
            "Year",
            "Quarter_Number",
            "Log_Values_USD_Millions",
            "Is_Financing"
        ]
    ].head(10)
)

# %% [markdown]
# ## Section 9: Business Insights and Recommendations (2.5 Marks)

# %% [markdown]
# ### Objective
#
# Translate the results of your data analysis into meaningful business insights relevant to Islamic banking. Your answers must be based on the analysis performed in Sections 1 to 8.

# %% [markdown]
# ### Task 9.1: Identify Key Findings
#
# Based on your EDA, visualization, time analysis, correlation analysis, and feature engineering, identify three important findings from the dataset.
#
# For each finding:
#
# 1. State the finding.
# 2. Provide supporting evidence from your analysis.
# 3. Explain why the finding may be relevant to Islamic banking.

# %% [markdown]
# ### Task 9.2: Identify a Potential Data or Modelling Risk
#
# Based on your analysis, identify one issue that could create a risk for future Machine Learning or predictive analytics.
#
# Possible areas include:
#
# - Missing values
# - Highly skewed variables
# - Outliers
# - Highly correlated variables
# - Unequal country representation
# - Data-type problems
# - Limited observations
#
# You must identify the issue from your own analysis and explain its potential impact.

# %% [markdown]
# ### Task 9.3: Recommend Additional Data
#
# Suppose the Islamic Bank wants to develop a future predictive analytics model using this dataset.
#
# > Identify three additional variables that you would recommend collecting.
#
# For each variable, explain why it would improve the analytical or predictive capability of the dataset.

# %% [markdown]
# ### Task 9.4: Management Recommendations
#
# Assume that you are presenting your findings to the Head of Data Analytics of an Islamic Bank.
#
# > Based on your analysis, provide three practical recommendations.
#
# Your recommendations must be:
#
# - Based on evidence from your analysis.
# - Relevant to Islamic banking.
# - Action-oriented.

# %% [markdown]
# ### Task 9.5: Executive Summary
#
# > Prepare a concise executive summary of approximately 150 to 200 words covering:
#
# - The purpose of the analysis.
# - The most important findings.
# - The major data-quality or modelling concern.
# - Your key recommendation.

# %% [markdown]
# ## Congratulations!
# You Have Completed Your Islamic FINTECH Final Practical Examination
#
# Congratulations on completing your Islamic FINTECH Final Practical Examination.
#
# > Through this project, you have applied the practical skills developed throughout the course, including Python programming, data cleaning, Exploratory Data Analysis, visualization, time-series analysis, correlation analysis, and feature engineering using Islamic banking data.
#
# > The purpose of this examination was not only to test your ability to write Python code, but also to assess your ability to understand data, identify meaningful patterns, solve analytical problems, and communicate insights from an Islamic banking perspective.
#
# Before submitting, please make sure that:
#
# - All sections have been completed.
# - All code cells have been executed.
# - Your interpretations and recommendations are included.
# - Your notebook is saved with the required filename.
# - The required files have been uploaded successfully to the examination portal.
#
# Congratulations once again on completing the course. I wish you success in your academic and professional journey.

# %% [markdown]
# ## Final Reminder
#
# - Check your notebook.
# - Save your work with your name and your student ID
# - Submit before the deadline via given upload link on the Folder.
