# %% [markdown]
# # Basic Python Practice Notebook (Finance & Islamic Finance)
#
# Complete each task by writing your own Python code in the code cell provided.

# %% [markdown]
# ## Print & Operators

# %% [markdown]
# ### Exercise 1
# **Task:** Print your name and program.

# %%
# Write your solution here

# %% [markdown]
# ### Exercise 2
# **Task:** Calculate: 250000 + 175000

# %%
# Write your solution here

# %% [markdown]
# ### Exercise 3
# **Task:** Calculate: 950000 - 425000

# %%
# Write your solution here

# %% [markdown]
# ### Exercise 4
# **Task:** Calculate: 125 * 48

# %%
# Write your solution here

# %% [markdown]
# ### Exercise 5
# **Task:** Calculate: 150000 / 12

# %%
# Write your solution here

# %% [markdown]
# ### Exercise 6
# **Task:** Find remainder of 1250 % 12

# %%
# Write your solution here

# %% [markdown]
# ### Exercise 7
# **Task:** Find floor division 1250 // 12

# %%
# Write your solution here

# %% [markdown]
# ### Exercise 8
# **Task:** Calculate 1.08 ** 5

# %%
# Write your solution here

# %% [markdown]
# ## Variables

# %% [markdown]
# ### Exercise 1
# **Task:** Create variables for share_price and number_of_shares. Calculate total investment.

# %%
# Write your solution here

# %% [markdown]
# ### Exercise 2
# **Task:** Create variables principal, rate, and time. Calculate simple interest.

# %%
# Write your solution here

# %% [markdown]
# ### Exercise 3
# **Task:** Create variables revenue and expenses. Calculate net profit.

# %%
# Write your solution here

# %% [markdown]
# ## Input Variables

# %% [markdown]
# ### Exercise 1
# **Task:** Take principal, rate and time as input and calculate simple interest.

# %%
# Write your solution here

# %% [markdown]
# ### Exercise 2
# **Task:** Take share price and quantity as input and calculate investment value.

# %%
# Write your solution here

# %% [markdown]
# ## Conditional Logic

# %% [markdown]
# ### Exercise 1
# **Task:** Determine whether a company made Profit or Loss using revenue and expenses.

# %%
# Write your solution here

# %% [markdown]
# ### Exercise 2
# **Task:** Recommend Buy/Hold/Avoid based on expected return using if-elif-else.

# %%
# Write your solution here

# %% [markdown]
# ### Exercise 3
# **Task:** Create a loan approval program using monthly income and credit score.

# %%
# Write your solution here

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Exercise 1
# **Task:** Write a function to calculate Gross Profit.

# %%
# Write your solution here

# %% [markdown]
# ### Exercise 2
# **Task:** Write a function to calculate Earnings per Share (EPS).

# %%
# Write your solution here

# %% [markdown]
# ## Loops

# %% [markdown]
# ### Exercise 1
# **Task:** Use a for loop to input investments of 5 investors and calculate total investment.

# %%
# Write your solution here

# %% [markdown]
# ### Exercise 2
# **Task:** Use a while loop to collect deposits until balance reaches Rs.500,000.

# %%
# Write your solution here

# %% [markdown]
# ## Islamic Finance

# %% [markdown]
# ### Exercise 1
# **Task:** Create a Shariah screening function using debt ratio and non-halal income.

# %%
# Write your solution here

# %% [markdown]
# ### Exercise 2
# **Task:** Create a Zakat eligibility program based on Nisab.

# %%
# Write your solution here

# %% [markdown]
# ### Exercise 3
# **Task:** Use a for loop to calculate Zakat for 3 customers.

# %%
# Write your solution here

# %% [markdown]
# ## Mini Project

# %% [markdown]
# ### Exercise 1
# **Task:** Develop a Finance Decision Support Program that asks the user to choose:
# 1. Simple Interest
# 2. Investment Value
# 3. Loan Approval
# 4. Zakat Eligibility
# Use functions, if-elif-else, and loops where appropriate.

# %%
# Write your solution here
