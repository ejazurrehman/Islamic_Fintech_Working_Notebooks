# %% [markdown]
# # EDA Project 01 (Version 2)
# # Exploratory Data Analysis of Global Islamic Banking Dataset
#
# ## Instructor Master Notebook
#
# **Course:** Islamic FinTech / Islamic Banking Analytics
#
# This notebook is designed as a complete teaching resource. Every section contains:
#
# - Learning Objective
# - Concept
# - Python Code
# - Expected Outcome
# - Instructor Notes
# - Discussion Questions

# %% [markdown]
# # Course Outcomes
#
# ## Learning Objective
# Students understand the complete EDA workflow for a real Islamic Banking dataset.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
# Instructor discussion / interpretation section.

# %% [markdown]
# # Step 1: Import Libraries
#
# ## Learning Objective
# Import Pandas, NumPy, Matplotlib and Seaborn.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns",None)
plt.rcParams["figure.figsize"]=(10,5)

# %% [markdown]
# # Step 2: Load Dataset
#
# ## Learning Objective
# Read the Excel workbook with the correct header row.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
file_path="ISLAMIC_BANKING_DATA_202606011047.xlsx"
df=pd.read_excel(file_path,header=7)
df.head()

# %% [markdown]
# # Step 3: Initial Exploration
#
# ## Learning Objective
# Inspect shape, columns and first observations.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
print(df.shape)
print(df.columns.tolist())
df.info()

# %% [markdown]
# # Step 4: Data Dictionary
#
# ## Learning Objective
# Identify variable types and business meaning.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
dictionary=pd.DataFrame({
'Variable':df.columns,
'Data Type':[str(x) for x in df.dtypes]
})
dictionary

# %% [markdown]
# # Step 5: Missing Value Analysis
#
# ## Learning Objective
# Measure missing values and discuss treatment.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
missing=df.isnull().sum().to_frame('Missing')
missing['Percent']=missing['Missing']/len(df)*100
missing.sort_values('Percent',ascending=False)

# %% [markdown]
# # Step 6: Duplicate Analysis
#
# ## Learning Objective
# Identify duplicated observations.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
df.duplicated().sum()

# %% [markdown]
# # Step 7: Data Type Validation
#
# ## Learning Objective
# Check and convert data types if required.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
df.describe(include='all').T

# %% [markdown]
# # Step 8: Descriptive Statistics
#
# ## Learning Objective
# Generate descriptive statistics.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
for c in df.select_dtypes(include='object').columns:
    print("\n",c)
    display(df[c].value_counts().head(10))

# %% [markdown]
# # Step 9: Categorical Analysis
#
# ## Learning Objective
# Analyse Country, Region, Report Type and Currency.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
df.select_dtypes(include=np.number).describe().T

# %% [markdown]
# # Step 10: Numerical Analysis
#
# ## Learning Objective
# Study exchange rate and financial values.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
for c in df.select_dtypes(include=np.number).columns:
    sns.boxplot(x=df[c])
    plt.title(c)
    plt.show()

# %% [markdown]
# # Step 11: Outlier Detection
#
# ## Learning Objective
# Use boxplots to identify extreme observations.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
if 'Time Period' in df.columns:
    df['Time Period'].value_counts().sort_index().plot(marker='o')
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# # Step 12: Time Series Analysis
#
# ## Learning Objective
# Explore quarterly reporting.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
if 'Country' in df.columns:
    df['Country'].value_counts().head(15).plot(kind='bar')
    plt.show()

# %% [markdown]
# # Step 13: Country Comparison
#
# ## Learning Objective
# Compare observations by country.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
if 'Indicator Description' in df.columns:
    df['Indicator Description'].value_counts().head(20).plot(kind='barh')
    plt.show()

# %% [markdown]
# # Step 14: Indicator Analysis
#
# ## Learning Objective
# Identify major reporting indicators.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
corr=df.select_dtypes(include=np.number).corr(numeric_only=True)
display(corr)
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# # Step 15: Correlation Analysis
#
# ## Learning Objective
# Generate correlation matrix.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
# Instructor discussion / interpretation section.

# %% [markdown]
# # Step 16: Business Interpretation
#
# ## Learning Objective
# Translate results into managerial insights.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
# Instructor discussion / interpretation section.

# %% [markdown]
# # Step 17: Student Reflection
#
# ## Learning Objective
# Critical thinking questions.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
# Instructor discussion / interpretation section.

# %% [markdown]
# # Step 18: Assignment
#
# ## Learning Objective
# Tasks for students.
#
# ### Instructor Notes
# Explain the purpose of this stage before running the code.
#
# ### Expected Outcome
# Students should be able to explain the output in business terms.
#
# ### Discussion
# - What did you observe?
# - Why is it important?
# - How does it help financial decision making?

# %%
# Instructor discussion / interpretation section.

# %% [markdown]
# # Final Instructor Checklist
#
# Before students submit, verify that they have:
#
# - Loaded the dataset correctly.
# - Explained each variable.
# - Checked missing values.
# - Analysed categorical variables.
# - Analysed numerical variables.
# - Produced at least 8 visualizations.
# - Written business interpretations for every major chart.
# - Summarized at least 10 key findings.
# - Proposed 5 managerial recommendations.
