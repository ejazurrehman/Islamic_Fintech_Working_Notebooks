# %% [markdown]
# # EDA Project 01 – Version 04 (Professional Instructor Edition)
#
# A structured instructor notebook with teaching notes, analytical workflow, and discussion prompts.

# %% [markdown]
# # Module 1: Environment Setup
#
# ## Learning Objective
# Import required libraries
#
# ### Banking Context
# Relate this step to Islamic banking reporting and decision-making.
#
# ### Expected Outcome
# Students should interpret the results, not just execute the code.
#
# ### Discussion Questions
# - What did you observe?
# - Why does it matter?
# - How could management use this information?
#
# ### Common Mistakes
# - Ignoring missing values
# - No interpretation after charts
# - Confusing counts with performance

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',None)

# %% [markdown]
# # Module 2: Load Dataset
#
# ## Learning Objective
# Load Excel data
#
# ### Banking Context
# Relate this step to Islamic banking reporting and decision-making.
#
# ### Expected Outcome
# Students should interpret the results, not just execute the code.
#
# ### Discussion Questions
# - What did you observe?
# - Why does it matter?
# - How could management use this information?
#
# ### Common Mistakes
# - Ignoring missing values
# - No interpretation after charts
# - Confusing counts with performance

# %%
file_path='ISLAMIC_BANKING_DATA_202606011047.xlsx'
df=pd.read_excel(file_path,header=7)
df.head()

# %% [markdown]
# # Module 3: Dataset Overview
#
# ## Learning Objective
# Inspect structure
#
# ### Banking Context
# Relate this step to Islamic banking reporting and decision-making.
#
# ### Expected Outcome
# Students should interpret the results, not just execute the code.
#
# ### Discussion Questions
# - What did you observe?
# - Why does it matter?
# - How could management use this information?
#
# ### Common Mistakes
# - Ignoring missing values
# - No interpretation after charts
# - Confusing counts with performance

# %%
print(df.shape)
display(df.head())
df.info()

# %% [markdown]
# # Module 4: Data Dictionary
#
# ## Learning Objective
# Create metadata
#
# ### Banking Context
# Relate this step to Islamic banking reporting and decision-making.
#
# ### Expected Outcome
# Students should interpret the results, not just execute the code.
#
# ### Discussion Questions
# - What did you observe?
# - Why does it matter?
# - How could management use this information?
#
# ### Common Mistakes
# - Ignoring missing values
# - No interpretation after charts
# - Confusing counts with performance

# %%
display(pd.DataFrame({'Variable':df.columns,'Type':df.dtypes.astype(str)}))

# %% [markdown]
# # Module 5: Data Quality
#
# ## Learning Objective
# Missing values and duplicates
#
# ### Banking Context
# Relate this step to Islamic banking reporting and decision-making.
#
# ### Expected Outcome
# Students should interpret the results, not just execute the code.
#
# ### Discussion Questions
# - What did you observe?
# - Why does it matter?
# - How could management use this information?
#
# ### Common Mistakes
# - Ignoring missing values
# - No interpretation after charts
# - Confusing counts with performance

# %%
mv=df.isnull().sum().to_frame('Missing');mv['Percent']=mv['Missing']/len(df)*100;display(mv.sort_values('Percent',ascending=False));print(df.duplicated().sum())

# %% [markdown]
# # Module 6: Descriptive Statistics
#
# ## Learning Objective
# Summary statistics
#
# ### Banking Context
# Relate this step to Islamic banking reporting and decision-making.
#
# ### Expected Outcome
# Students should interpret the results, not just execute the code.
#
# ### Discussion Questions
# - What did you observe?
# - Why does it matter?
# - How could management use this information?
#
# ### Common Mistakes
# - Ignoring missing values
# - No interpretation after charts
# - Confusing counts with performance

# %%
display(df.describe(include='all').T)

# %% [markdown]
# # Module 7: Categorical Analysis
#
# ## Learning Objective
# Explore categorical variables
#
# ### Banking Context
# Relate this step to Islamic banking reporting and decision-making.
#
# ### Expected Outcome
# Students should interpret the results, not just execute the code.
#
# ### Discussion Questions
# - What did you observe?
# - Why does it matter?
# - How could management use this information?
#
# ### Common Mistakes
# - Ignoring missing values
# - No interpretation after charts
# - Confusing counts with performance

# %%
for c in df.select_dtypes(include='object').columns:
    display(df[c].value_counts().head(10))

# %% [markdown]
# # Module 8: Numerical Analysis
#
# ## Learning Objective
# Explore numerical variables
#
# ### Banking Context
# Relate this step to Islamic banking reporting and decision-making.
#
# ### Expected Outcome
# Students should interpret the results, not just execute the code.
#
# ### Discussion Questions
# - What did you observe?
# - Why does it matter?
# - How could management use this information?
#
# ### Common Mistakes
# - Ignoring missing values
# - No interpretation after charts
# - Confusing counts with performance

# %%
display(df.select_dtypes(include=np.number).describe().T)

# %% [markdown]
# # Module 9: Visualizations
#
# ## Learning Objective
# Histograms and boxplots
#
# ### Banking Context
# Relate this step to Islamic banking reporting and decision-making.
#
# ### Expected Outcome
# Students should interpret the results, not just execute the code.
#
# ### Discussion Questions
# - What did you observe?
# - Why does it matter?
# - How could management use this information?
#
# ### Common Mistakes
# - Ignoring missing values
# - No interpretation after charts
# - Confusing counts with performance

# %%
for c in df.select_dtypes(include=np.number).columns:
    sns.histplot(df[c].dropna(),kde=True);plt.title(c);plt.show()

# %% [markdown]
# # Module 10: Country Analysis
#
# ## Learning Objective
# Country comparison
#
# ### Banking Context
# Relate this step to Islamic banking reporting and decision-making.
#
# ### Expected Outcome
# Students should interpret the results, not just execute the code.
#
# ### Discussion Questions
# - What did you observe?
# - Why does it matter?
# - How could management use this information?
#
# ### Common Mistakes
# - Ignoring missing values
# - No interpretation after charts
# - Confusing counts with performance

# %%
if 'Country' in df.columns:
    df['Country'].value_counts().head(15).plot(kind='bar');plt.show()

# %% [markdown]
# # Module 11: Regional Analysis
#
# ## Learning Objective
# Regional comparison
#
# ### Banking Context
# Relate this step to Islamic banking reporting and decision-making.
#
# ### Expected Outcome
# Students should interpret the results, not just execute the code.
#
# ### Discussion Questions
# - What did you observe?
# - Why does it matter?
# - How could management use this information?
#
# ### Common Mistakes
# - Ignoring missing values
# - No interpretation after charts
# - Confusing counts with performance

# %%
if 'Regional Code' in df.columns:
    df['Regional Code'].value_counts().plot(kind='bar');plt.show()

# %% [markdown]
# # Module 12: Report Type
#
# ## Learning Objective
# Analyse report types
#
# ### Banking Context
# Relate this step to Islamic banking reporting and decision-making.
#
# ### Expected Outcome
# Students should interpret the results, not just execute the code.
#
# ### Discussion Questions
# - What did you observe?
# - Why does it matter?
# - How could management use this information?
#
# ### Common Mistakes
# - Ignoring missing values
# - No interpretation after charts
# - Confusing counts with performance

# %%
if 'Report Type' in df.columns:
    df['Report Type'].value_counts().plot(kind='bar');plt.show()

# %% [markdown]
# # Module 13: Indicator Analysis
#
# ## Learning Objective
# Top indicators
#
# ### Banking Context
# Relate this step to Islamic banking reporting and decision-making.
#
# ### Expected Outcome
# Students should interpret the results, not just execute the code.
#
# ### Discussion Questions
# - What did you observe?
# - Why does it matter?
# - How could management use this information?
#
# ### Common Mistakes
# - Ignoring missing values
# - No interpretation after charts
# - Confusing counts with performance

# %%
if 'Indicator Description' in df.columns:
    df['Indicator Description'].value_counts().head(20).plot(kind='barh');plt.show()

# %% [markdown]
# # Module 14: Time Analysis
#
# ## Learning Objective
# Quarterly analysis
#
# ### Banking Context
# Relate this step to Islamic banking reporting and decision-making.
#
# ### Expected Outcome
# Students should interpret the results, not just execute the code.
#
# ### Discussion Questions
# - What did you observe?
# - Why does it matter?
# - How could management use this information?
#
# ### Common Mistakes
# - Ignoring missing values
# - No interpretation after charts
# - Confusing counts with performance

# %%
if 'Time Period' in df.columns:
    df['Time Period'].value_counts().sort_index().plot(marker='o');plt.xticks(rotation=90);plt.show()

# %% [markdown]
# # Module 15: Correlation
#
# ## Learning Objective
# Relationships
#
# ### Banking Context
# Relate this step to Islamic banking reporting and decision-making.
#
# ### Expected Outcome
# Students should interpret the results, not just execute the code.
#
# ### Discussion Questions
# - What did you observe?
# - Why does it matter?
# - How could management use this information?
#
# ### Common Mistakes
# - Ignoring missing values
# - No interpretation after charts
# - Confusing counts with performance

# %%
corr=df.select_dtypes(include=np.number).corr(numeric_only=True);display(corr);sns.heatmap(corr,annot=True);plt.show()

# %% [markdown]
# # Module 16: Business Insights
#
# ## Learning Objective
# Interpretation
#
# ### Banking Context
# Relate this step to Islamic banking reporting and decision-making.
#
# ### Expected Outcome
# Students should interpret the results, not just execute the code.
#
# ### Discussion Questions
# - What did you observe?
# - Why does it matter?
# - How could management use this information?
#
# ### Common Mistakes
# - Ignoring missing values
# - No interpretation after charts
# - Confusing counts with performance

# %%
# Write business insights here

# %% [markdown]
# # Module 17: Mini Case
#
# ## Learning Objective
# Country case study
#
# ### Banking Context
# Relate this step to Islamic banking reporting and decision-making.
#
# ### Expected Outcome
# Students should interpret the results, not just execute the code.
#
# ### Discussion Questions
# - What did you observe?
# - Why does it matter?
# - How could management use this information?
#
# ### Common Mistakes
# - Ignoring missing values
# - No interpretation after charts
# - Confusing counts with performance

# %%
# Repeat analysis for Pakistan or another country

# %% [markdown]
# # Module 18: Executive Summary
#
# ## Learning Objective
# Summarize findings
#
# ### Banking Context
# Relate this step to Islamic banking reporting and decision-making.
#
# ### Expected Outcome
# Students should interpret the results, not just execute the code.
#
# ### Discussion Questions
# - What did you observe?
# - Why does it matter?
# - How could management use this information?
#
# ### Common Mistakes
# - Ignoring missing values
# - No interpretation after charts
# - Confusing counts with performance

# %%
# Executive summary

# %% [markdown]
# ## Instructor Checklist
#
# - Dataset loaded
# - Quality checked
# - At least 10 charts
# - Business insights documented
# - Executive summary completed
