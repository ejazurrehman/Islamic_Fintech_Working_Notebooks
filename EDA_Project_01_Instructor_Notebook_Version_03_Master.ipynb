# %% [markdown]
# # EDA Project 01 – Version 03
# # Global Islamic Banking Dataset (Instructor Master Edition)
#
# This notebook is intended to be the **master instructor notebook** for teaching Exploratory Data Analysis (EDA) with a real Islamic Banking dataset.
#
# Each section includes:
# - Learning objectives
# - Banking context
# - Python implementation
# - Expected output
# - Interpretation guide
# - Discussion questions
# - Common mistakes
# - Extension activity

# %% [markdown]
# # Project Overview
#
# Introduce students to real-world Islamic banking supervisory data and the EDA lifecycle.

# %% [markdown]
# # Dataset Background
#
# Discuss the IFSB, reporting frequency, countries, indicators, and supervisory reporting.

# %% [markdown]
# # EDA Workflow
#
# Explain the CRISP-DM inspired EDA process: Understand → Clean → Explore → Visualize → Interpret.

# %% [markdown]
# # Module 1: Import Libraries
#
# ## Learning Objective
# Import analysis libraries.
#
# ### Banking Context
# Relate this analysis to Islamic banking supervision, financial reporting, and managerial decision-making.
#
# ### Expected Output
# Students should describe **what the output shows** and **why it matters**.
#
# ### Instructor Interpretation
# Explain the business meaning, not only the Python output.
#
# ### Common Student Mistakes
# - Misinterpreting missing values
# - Ignoring data types
# - Drawing conclusions from raw counts without context
#
# ### Extension Activity
# Ask students to repeat the analysis for a selected country or indicator.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',None)
plt.rcParams['figure.figsize']=(10,5)

# %% [markdown]
# # Module 2: Load Dataset
#
# ## Learning Objective
# Load the Excel file (header row = 8).
#
# ### Banking Context
# Relate this analysis to Islamic banking supervision, financial reporting, and managerial decision-making.
#
# ### Expected Output
# Students should describe **what the output shows** and **why it matters**.
#
# ### Instructor Interpretation
# Explain the business meaning, not only the Python output.
#
# ### Common Student Mistakes
# - Misinterpreting missing values
# - Ignoring data types
# - Drawing conclusions from raw counts without context
#
# ### Extension Activity
# Ask students to repeat the analysis for a selected country or indicator.

# %%
file_path='ISLAMIC_BANKING_DATA_202606011047.xlsx'
df=pd.read_excel(file_path,header=7)
df.head()

# %% [markdown]
# # Module 3: Quick Inspection
#
# ## Learning Objective
# Understand dimensions and variables.
#
# ### Banking Context
# Relate this analysis to Islamic banking supervision, financial reporting, and managerial decision-making.
#
# ### Expected Output
# Students should describe **what the output shows** and **why it matters**.
#
# ### Instructor Interpretation
# Explain the business meaning, not only the Python output.
#
# ### Common Student Mistakes
# - Misinterpreting missing values
# - Ignoring data types
# - Drawing conclusions from raw counts without context
#
# ### Extension Activity
# Ask students to repeat the analysis for a selected country or indicator.

# %%
print(df.shape)
display(df.head())
display(df.tail())
df.info()

# %% [markdown]
# # Module 4: Create Data Dictionary
#
# ## Learning Objective
# Summarize variables and types.
#
# ### Banking Context
# Relate this analysis to Islamic banking supervision, financial reporting, and managerial decision-making.
#
# ### Expected Output
# Students should describe **what the output shows** and **why it matters**.
#
# ### Instructor Interpretation
# Explain the business meaning, not only the Python output.
#
# ### Common Student Mistakes
# - Misinterpreting missing values
# - Ignoring data types
# - Drawing conclusions from raw counts without context
#
# ### Extension Activity
# Ask students to repeat the analysis for a selected country or indicator.

# %%
pd.DataFrame({'Variable':df.columns,'Type':df.dtypes.astype(str)})

# %% [markdown]
# # Module 5: Missing Values
#
# ## Learning Objective
# Quantify missing values.
#
# ### Banking Context
# Relate this analysis to Islamic banking supervision, financial reporting, and managerial decision-making.
#
# ### Expected Output
# Students should describe **what the output shows** and **why it matters**.
#
# ### Instructor Interpretation
# Explain the business meaning, not only the Python output.
#
# ### Common Student Mistakes
# - Misinterpreting missing values
# - Ignoring data types
# - Drawing conclusions from raw counts without context
#
# ### Extension Activity
# Ask students to repeat the analysis for a selected country or indicator.

# %%
mv=df.isnull().sum().to_frame('Missing')
mv['Percent']=mv['Missing']/len(df)*100
mv.sort_values('Percent',ascending=False)

# %% [markdown]
# # Module 6: Duplicates
#
# ## Learning Objective
# Check duplicate records.
#
# ### Banking Context
# Relate this analysis to Islamic banking supervision, financial reporting, and managerial decision-making.
#
# ### Expected Output
# Students should describe **what the output shows** and **why it matters**.
#
# ### Instructor Interpretation
# Explain the business meaning, not only the Python output.
#
# ### Common Student Mistakes
# - Misinterpreting missing values
# - Ignoring data types
# - Drawing conclusions from raw counts without context
#
# ### Extension Activity
# Ask students to repeat the analysis for a selected country or indicator.

# %%
df.duplicated().sum()

# %% [markdown]
# # Module 7: Summary Statistics
#
# ## Learning Objective
# Describe numeric variables.
#
# ### Banking Context
# Relate this analysis to Islamic banking supervision, financial reporting, and managerial decision-making.
#
# ### Expected Output
# Students should describe **what the output shows** and **why it matters**.
#
# ### Instructor Interpretation
# Explain the business meaning, not only the Python output.
#
# ### Common Student Mistakes
# - Misinterpreting missing values
# - Ignoring data types
# - Drawing conclusions from raw counts without context
#
# ### Extension Activity
# Ask students to repeat the analysis for a selected country or indicator.

# %%
df.describe(include='all').T

# %% [markdown]
# # Module 8: Categorical Analysis
#
# ## Learning Objective
# Frequency analysis.
#
# ### Banking Context
# Relate this analysis to Islamic banking supervision, financial reporting, and managerial decision-making.
#
# ### Expected Output
# Students should describe **what the output shows** and **why it matters**.
#
# ### Instructor Interpretation
# Explain the business meaning, not only the Python output.
#
# ### Common Student Mistakes
# - Misinterpreting missing values
# - Ignoring data types
# - Drawing conclusions from raw counts without context
#
# ### Extension Activity
# Ask students to repeat the analysis for a selected country or indicator.

# %%
for c in df.select_dtypes(include='object').columns:
    display(df[c].value_counts().head(10))

# %% [markdown]
# # Module 9: Numeric Analysis
#
# ## Learning Objective
# Distribution analysis.
#
# ### Banking Context
# Relate this analysis to Islamic banking supervision, financial reporting, and managerial decision-making.
#
# ### Expected Output
# Students should describe **what the output shows** and **why it matters**.
#
# ### Instructor Interpretation
# Explain the business meaning, not only the Python output.
#
# ### Common Student Mistakes
# - Misinterpreting missing values
# - Ignoring data types
# - Drawing conclusions from raw counts without context
#
# ### Extension Activity
# Ask students to repeat the analysis for a selected country or indicator.

# %%
num=df.select_dtypes(include=np.number)
display(num.describe().T)

# %% [markdown]
# # Module 10: Histograms
#
# ## Learning Objective
# Visualize distributions.
#
# ### Banking Context
# Relate this analysis to Islamic banking supervision, financial reporting, and managerial decision-making.
#
# ### Expected Output
# Students should describe **what the output shows** and **why it matters**.
#
# ### Instructor Interpretation
# Explain the business meaning, not only the Python output.
#
# ### Common Student Mistakes
# - Misinterpreting missing values
# - Ignoring data types
# - Drawing conclusions from raw counts without context
#
# ### Extension Activity
# Ask students to repeat the analysis for a selected country or indicator.

# %%
for c in df.select_dtypes(include=np.number).columns:
    plt.figure()
    sns.histplot(df[c].dropna(),kde=True)
    plt.title(c)
    plt.show()

# %% [markdown]
# # Module 11: Boxplots
#
# ## Learning Objective
# Detect outliers.
#
# ### Banking Context
# Relate this analysis to Islamic banking supervision, financial reporting, and managerial decision-making.
#
# ### Expected Output
# Students should describe **what the output shows** and **why it matters**.
#
# ### Instructor Interpretation
# Explain the business meaning, not only the Python output.
#
# ### Common Student Mistakes
# - Misinterpreting missing values
# - Ignoring data types
# - Drawing conclusions from raw counts without context
#
# ### Extension Activity
# Ask students to repeat the analysis for a selected country or indicator.

# %%
for c in df.select_dtypes(include=np.number).columns:
    plt.figure()
    sns.boxplot(x=df[c])
    plt.title(c)
    plt.show()

# %% [markdown]
# # Module 12: Country Analysis
#
# ## Learning Objective
# Top reporting countries.
#
# ### Banking Context
# Relate this analysis to Islamic banking supervision, financial reporting, and managerial decision-making.
#
# ### Expected Output
# Students should describe **what the output shows** and **why it matters**.
#
# ### Instructor Interpretation
# Explain the business meaning, not only the Python output.
#
# ### Common Student Mistakes
# - Misinterpreting missing values
# - Ignoring data types
# - Drawing conclusions from raw counts without context
#
# ### Extension Activity
# Ask students to repeat the analysis for a selected country or indicator.

# %%
if 'Country' in df.columns:
    df['Country'].value_counts().head(15).plot(kind='bar')
    plt.title('Top Countries')
    plt.show()

# %% [markdown]
# # Module 13: Report Type Analysis
#
# ## Learning Objective
# Compare report types.
#
# ### Banking Context
# Relate this analysis to Islamic banking supervision, financial reporting, and managerial decision-making.
#
# ### Expected Output
# Students should describe **what the output shows** and **why it matters**.
#
# ### Instructor Interpretation
# Explain the business meaning, not only the Python output.
#
# ### Common Student Mistakes
# - Misinterpreting missing values
# - Ignoring data types
# - Drawing conclusions from raw counts without context
#
# ### Extension Activity
# Ask students to repeat the analysis for a selected country or indicator.

# %%
if 'Report Type' in df.columns:
    df['Report Type'].value_counts().plot(kind='bar')

# %% [markdown]
# # Module 14: Indicator Analysis
#
# ## Learning Objective
# Most common indicators.
#
# ### Banking Context
# Relate this analysis to Islamic banking supervision, financial reporting, and managerial decision-making.
#
# ### Expected Output
# Students should describe **what the output shows** and **why it matters**.
#
# ### Instructor Interpretation
# Explain the business meaning, not only the Python output.
#
# ### Common Student Mistakes
# - Misinterpreting missing values
# - Ignoring data types
# - Drawing conclusions from raw counts without context
#
# ### Extension Activity
# Ask students to repeat the analysis for a selected country or indicator.

# %%
if 'Indicator Description' in df.columns:
    df['Indicator Description'].value_counts().head(20).plot(kind='barh')

# %% [markdown]
# # Module 15: Time Analysis
#
# ## Learning Objective
# Quarterly reporting.
#
# ### Banking Context
# Relate this analysis to Islamic banking supervision, financial reporting, and managerial decision-making.
#
# ### Expected Output
# Students should describe **what the output shows** and **why it matters**.
#
# ### Instructor Interpretation
# Explain the business meaning, not only the Python output.
#
# ### Common Student Mistakes
# - Misinterpreting missing values
# - Ignoring data types
# - Drawing conclusions from raw counts without context
#
# ### Extension Activity
# Ask students to repeat the analysis for a selected country or indicator.

# %%
if 'Time Period' in df.columns:
    df['Time Period'].value_counts().sort_index().plot(marker='o')
    plt.xticks(rotation=90)
    plt.show()

# %% [markdown]
# # Module 16: Correlation
#
# ## Learning Objective
# Relationship among numeric variables.
#
# ### Banking Context
# Relate this analysis to Islamic banking supervision, financial reporting, and managerial decision-making.
#
# ### Expected Output
# Students should describe **what the output shows** and **why it matters**.
#
# ### Instructor Interpretation
# Explain the business meaning, not only the Python output.
#
# ### Common Student Mistakes
# - Misinterpreting missing values
# - Ignoring data types
# - Drawing conclusions from raw counts without context
#
# ### Extension Activity
# Ask students to repeat the analysis for a selected country or indicator.

# %%
corr=df.select_dtypes(include=np.number).corr(numeric_only=True)
display(corr)
plt.figure(figsize=(8,6))
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# # Module 17: Mini Case Study
#
# ## Learning Objective
# Select Pakistan (or another country) and explore trends.
#
# ### Banking Context
# Relate this analysis to Islamic banking supervision, financial reporting, and managerial decision-making.
#
# ### Expected Output
# Students should describe **what the output shows** and **why it matters**.
#
# ### Instructor Interpretation
# Explain the business meaning, not only the Python output.
#
# ### Common Student Mistakes
# - Misinterpreting missing values
# - Ignoring data types
# - Drawing conclusions from raw counts without context
#
# ### Extension Activity
# Ask students to repeat the analysis for a selected country or indicator.

# %%
# Example
# pakistan=df[df['Country']=='Pakistan']

# %% [markdown]
# # Module 18: Business Insights
#
# ## Learning Objective
# Document findings.
#
# ### Banking Context
# Relate this analysis to Islamic banking supervision, financial reporting, and managerial decision-making.
#
# ### Expected Output
# Students should describe **what the output shows** and **why it matters**.
#
# ### Instructor Interpretation
# Explain the business meaning, not only the Python output.
#
# ### Common Student Mistakes
# - Misinterpreting missing values
# - Ignoring data types
# - Drawing conclusions from raw counts without context
#
# ### Extension Activity
# Ask students to repeat the analysis for a selected country or indicator.

# %%
# Write at least 10 findings and 5 recommendations.

# %% [markdown]
# # Capstone Reflection
#
# ## Deliverables
# - Clean notebook
# - At least 12 charts
# - 10 business findings
# - 5 managerial recommendations
# - 3 limitations
# - 3 ideas for future analysis
#
# ## Next Project
# EDA Project 02: Pakistan Islamic Banking Sector Analysis
